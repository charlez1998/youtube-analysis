# %%
import requests
import pandas as pd 
import time

# %%
#KEYS
API_KEY = "AIzaSyCgJyrNHpqmXTibvv0OmnMzu6nOBUABL8I"
#CHANNEL_ID = "UCp_JsnV5TZMT2DIIZHwINPA"
CHANNEL_ID = "UCn8zNIfYAQNdrFRrr8oibKw"

# %%
def get_video_details(video_id):        
        #collecting view, like, comment counts
        url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
        response_video_stats = requests.get(url_video_stats).json()

        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        comment_count =  response_video_stats['items'][0]['statistics']['commentCount']
        
        return view_count, like_count, comment_count

# %%
def get_videos(df):
    #make API call
    pageToken = ''
    url = 'https://www.googleapis.com/youtube/v3/search?key='+API_KEY+'&channelId='+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken
    response = requests.get(url).json()
    
    time.sleep(1)
    
    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]

            view_count, like_count, comment_count = get_video_details(video_id)

            #save date in pandas df
            df = df.append({'video_id' : video_id, 'video_title':video_title, 
                            'upload_date' :upload_date, 'view_count' :view_count,
                            'like_count' :like_count, 'comment_count' : comment_count}, ignore_index = True)
    return df

# %%
#create empty dataframe
df = pd.DataFrame(columns = ['video_id', 'video_title', 'upload_date', 'view_count', 'like_count', 'comment_count'])

df = get_videos(df)

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   rrhOQKDC5sY  One of the Most-Watched Women on Twitch: Amour...
# 1   a0cDdo-H5Vo  The Story of &#39;Because I Got High&#39; by A...
# 2   D4ns79sFSvE              The Teenage Mafia Academy | Crimewave
# 3   5A7NuXzKdUM  My Disability Comedy is Not Your “Inspiration ...
# 4   a_ee6XDSDBQ  Is this Royal Club Just Empire in Disguise? | ...
# 5   9W43aeRl4C0    The Gangs Turning Children into Dealers #Shorts
# 6   gVJx8tCoiKE     Getting Stepped on for a Living | Side Hustles
# 7   Oge1nNcIjZg  Why Adult Babies Enjoy Having Their Diapers Ch...
# 8   YJZUMX5PZ7U  The Story of &#39;Unwritten&#39; By Natasha Be...
# 9   ZZI04-3vwC0      I Was Put Up ‘For Sale&#39; as a Muslim Woman
# 10  oADU2PIzhD0  The Legendary Song That Became the Rick Roll |...
# 11  cYZkvmEjvuI  The U.S. Military Contracted Burn Pits No One ...
# 12  Q6wBh7UcHqo  From YouTube Daredevil to Internet Outcast | M...
# 13  poHTA94-BeY  What North Korea Doesn’t Want You To See | Sup...
# 14  yELoQjXupzU  100,000 Calorie Challenges: Inside the World O...
# 15  -ZhxFtmAoXg  MS13&#39;s Toxic Weed That’s “More Addictive T...
# 16  zCIFBLhHEQw  Living With A Dissociative Disorder | My Life ...
# 17  2rICKAcU-Oc  Surviving Prison as a Gay Ex-Hitman | Imperdon...
# 18  U4H9kDL-WmU       Adult Baby Diaper Lovers | VICE Guide to Sex
# 19  ry66uECjbdY  This is How Drugs Get Smuggled Into Europe | I...
# 20  XQc6mJ7u8gQ    Putin’s Secret Neo-Nazi Armies | Decade of Hate
# 21  CrYzKbAwu34  Training To Be a Hitman for the Cartel | Rites...
# 22  -3Cv-7WU4Qo  New Crystal Meth is Stronger Than Ever | High ...
# 23  s8SGOjTr2GM                      I Was a North Korean Assassin
# 24  z8saOxMkJFI  The World’s Deadliest Drug War Just Got a New ...
# 25  bXkn-fvC_M4         I Expose the Worst Landlords | Super Users
# 26  lFIro2Dnfj8  Las Vegas’s Duke of Guns, Gambling, and Gold |...
# 27  PsZpnoELOus  The VICE Guide to Vegas Pt 1: Counting Cards, ...
# 28  j54mZrCZCqk                What to Expect: VICE Guide to Vegas
# 29  99XQY7Elwhc  Pissing Blood: The Ketamine Time Bomb | High S...
# 30  gciEIuLNKNE            Colombia’s Pink “Cocaine” Craze #Shorts
# 31  4PfZlxhvdkM  The Replacement Conspiracy Inspiring Mass Shoo...
# 32  y3jvZga60pI  How You Measure Up To The Perfect Penis | Spir...
# 33  O57Vwi8jtKc                 From Yakuza Gangster to Politician
# 34  XZRmFLgXr4Q     Reality Show Recruits a VICE Presenter #Shorts
# 35  JDGg1I60mPs       How a Cheater Thinks |  Kevin Gates Helpline
# 36  VqOdnCEbDU4  Ukrainians Are Bombing Russians with Custom Dr...
# 37  2qIsQw_gOU8  Sharing Home Cooked Syrian Food in Lebanon I O...
# 38  lrLj07xD-XY  Can You Be In Love With Two People? | Kevin Ga...
# 39  VOjAlLoXOhQ             The Pink “Cocaine” Wave | High Society
# 40  j5YKKPizQi8  Inside Hong Kong&#39;s Fight for Freedom | Fac...
# 41  OA6XdaiRRHo  The King of Coney Island - Bing Bong | Local L...
# 42  rEN07ZBsM5E  How Speed is Fuelling Wars in The Middle East ...
# 43  aKwkMZbeeGo  Tricking My Way Into NYC&#39;s Billionaire Pen...
# 44  oqoE6_rhbbY   Why Can&#39;t I Get Laid? | Kevin Gates Helpline
# 45  qKjg3VeW4LQ  Last Meal Requests of Death Row Inmates | Last...
# 46  S-kYompsyLU  Growing Up With Jean-Michel Basquiat | I Was T...
# 47  oUWJX9k8QZk  Jumping off a Cliff With a One-Star Paraglider...
# 48  i0ZbfkBCwtk  Conspiracy Theorists Are Creating Their Own Na...
# 49  ri7IDNT8vI0       The Man Who Flies with Birds | Local Legends
#
#    upload_date view_count like_count comment_count
# 0   2022-11-06      17908        880           260
# 1   2022-11-05     587425      22531          2534
# 2   2022-11-04     585193      12384          1807
# 3   2022-11-03      88655       2236           503
# 4   2022-11-02     205130       1864           686
# 5   2022-10-31      61603       1794            82
# 6   2022-10-30     219844       3403           911
# 7   2022-10-28     101823       1282           721
# 8   2022-10-16     347093       8935           916
# 9   2022-10-11     128374       2548          1004
# 10  2022-10-08    1663974      74891          5307
# 11  2022-09-30    1847463      23533          4188
# 12  2022-09-25     348904       4184          1955
# 13  2022-09-21    3227624      60211          3476
# 14  2022-09-11     269451       5571          1170
# 15  2022-09-10    4576912      52278         11700
# 16  2022-09-09     310852       6686          1744
# 17  2022-09-01     616006       8336          1425
# 18  2022-08-28     761918       6141          3524
# 19  2022-08-26     599175      10498          1089
# 20  2022-08-22     933240      19176          7473
# 21  2022-08-21     715458      28850          2714
# 22  2022-08-14     758103      14682          4648
# 23  2022-08-08     298292       6809           445
# 24  2022-07-29     673535      12367          3675
# 25  2022-07-28     497814       9202          1025
# 26  2022-07-24     251332       4274           589
# 27  2022-07-18     643883      15972          1362
# 28  2022-07-17     144175       1549           100
# 29  2022-07-16    2641067      54854          9853
# 30  2022-07-09    1638956      25699          2883
# 31  2022-07-08    1453034      26922          9303
# 32  2022-06-26     684808      11787          2611
# 33  2022-06-25     240993       4369           452
# 34  2022-06-23      86145       1088            60
# 35  2022-06-19     317727       8040           543
# 36  2022-06-17    1693262      20625          2096
# 37  2022-06-15      70257       1471           209
# 38  2022-06-05     163669       4292           321
# 39  2022-06-04    3981782     115329         17269
# 40  2022-06-02     352598       6705           966
# 41  2022-05-14    1453361      28206          2845
# 42  2022-05-13     282088       5233           789
# 43  2022-05-09    3820736      63630          3950
# 44  2022-05-08     218978       6208           430
# 45  2022-05-05     824931      12332           987
# 46  2022-04-30     539722      21730           906
# 47  2022-04-17     888401      20839          1589
# 48  2022-04-14     782600      11927          6638
# 49  2022-04-10      93751       2014           255

# %% [markdown]
# ## Part 2

# %%
import psycopg2 as ps

# %%
def connect_to_db(host_name, dbname, port, username, password):
    try: 
        conn = ps.connect(host = host_name,database = dbname, user = username, password = password, port = port)
    except ps.OperationalError as e:
        raise e
    else:
        print("Connected")
    return conn

# %%
#create table
def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS videos(
                            video_id VARCHAR(255) PRIMARY KEY,
                            video_title TEXT NOT NULL,
                            upload_date DATE NOT NULL DEFAULT CURRENT_DATE,
                            view_count INTEGER NOT NULL,
                            like_count INTEGER NOT NULL,
                            comment_count INTEGER NOT NULL)
                            """)
    curr.execute(create_table_command)

# %%
#check if video exists
def check_if_video_exists(curr, video_id):
    query = ("""SELECT video_id FROM VIDEOS WHERE video_id = %s""")
    curr.execute(query, (video_id,))
    return curr.fetchone() is not None

# %%
#update row if video exists 
def update_row(curr, video_id, video_title, view_count, like_count, comment_count):
    query = ("""UPDATE videos 
                SET video_title = %s,
                    view_count = %s,
                    like_count = %s,
                    comment_count = %s
                WHERE video_id = %s;""")

    vars_to_update = (video_title, view_count, like_count, comment_count, video_id)
    curr.execute(query, vars_to_update)

# %%
#update the database
#handling data for scalability

#check to see if video exists
def update_db(curr,df):
    tmp_df = pd.DataFrame(columns = ["video_id", "video_title", "upload_date", "view_count", "like_count", "comment_count"])

    for i, row in df.iterrows():
        if check_if_video_exists(curr, row['video_id']): #if the video already exists then we will update
            update_row(curr, row['video_id'], row['video_title'], row['view_count'], row['like_count'], row['comment_count']) 
        else: #the video doesn't exist so we will append to the db table
            tmp_df = tmp_df.append(row)
    return tmp_df

# %%
#write insert command

def insert_into_table(curr, video_id, video_title, upload_date, view_count, like_count, comment_count):
    insert_into_videos = ("""INSERT INTO videos (video_id, video_title, upload_date, view_count, like_count, comment_count)
        VALUES (%s, %s, %s, %s, %s, %s);""")

    row_to_insert = (video_id, video_title, upload_date, view_count, like_count, comment_count)

    curr.execute(insert_into_videos, row_to_insert)

# %%
def append_from_df_to_db(curr, df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['video_id'], row['video_title'], row['upload_date'], row['view_count'], row['like_count'], row['comment_count'])

# %%
host_name = 'database-proj.czyjaiztu7sr.ap-southeast-1.rds.amazonaws.com'
dbname = 'charliedb'
port = '5432'
username= 'charlie' 
password= 'testpassword'
conn = None

conn = connect_to_db(host_name, dbname, port, username, password)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-56-1ffb15c4c48f> in <module>
#       6 conn = None
#       7
# ----> 8 conn = connect_to_db(host_name, dbname, port, username, password)
#
# <ipython-input-49-f6799413a3b2> in connect_to_db(host_name, dbname, port, username, password)
#       3         conn = ps.connect(host = host_name,database = dbname, user = username, password = password, port = port)
#       4     except ps.OperationalError as e:
# ----> 5         raise e
#       6     else:
#       7         print("Connected")
#
# <ipython-input-49-f6799413a3b2> in connect_to_db(host_name, dbname, port, username, password)
#       1 def connect_to_db(host_name, dbname, port, username, password):
#       2     try:
# ----> 3         conn = ps.connect(host = host_name,database = dbname, user = username, password = password, port = port)
#       4     except ps.OperationalError as e:
#       5         raise e
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: could not translate host name "database-proj.czyjaiztu7sr.ap-southeast-1.rds.amazonaws.com" to address: Unknown host
